# %%
# import the general stuff
import os
from os import getcwd
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
#from sklearn import metrics
#import math

#import stuff for gradCAM
#import matplotlib.cm as cm
#from IPython.display import Image

#If nm,ultiople GPU, set which GPU to use
#os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"] = "0"

#import the tf stuff
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model

from tensorflow.keras.preprocessing.image import ImageDataGenerator

#Check TensorFlow Version
print('TF version: {}' .format(tf.__version__))
# Out:
# TF version: 2.3.2

# %%
# #code for GPU mem growth needed for EBG Laptop

# from tensorflow.compat.v1 import ConfigProto
# from tensorflow.compat.v1 import InteractiveSession

# config = ConfigProto()
# config.gpu_options.allow_growth = True
# session = InteractiveSession(config=config)

# %%
#Check for GPU utilization
if tf.test.gpu_device_name():
    print(' GPU: {}'.format(tf.test.gpu_device_name()))
else:
    print("No GPU")
# Out:
#  GPU: /device:GPU:0

# %%
#data
df = pd.read_csv('../data/SedMLdata.csv')
df.head()
# Out:
#       CropName   D2mm   D5mm  D10mm  D16mm  D25mm  D50mm  D75mm  D84mm  D90mm  \
# 0  F1crop1.jpg  0.202  0.255  0.328  0.417  0.600  1.049  1.475  1.690  1.941
# 1  F1crop2.jpg  0.168  0.194  0.224  0.256  0.305  0.481  0.974  1.420  2.143
# 2  F1crop3.jpg  0.128  0.144  0.160  0.176  0.198  0.304  0.540  0.700  0.897
# 3  F1crop4.jpg  0.218  0.273  0.346  0.429  0.621  1.283  1.821  2.040  2.241
# 4  F1crop5.jpg  0.134  0.153  0.174  0.194  0.221  0.332  0.780  1.139  1.532
#
#    D95mm  D98mm   skew  kurtosis
# 0  2.243  2.621 -0.310     0.992
# 1  2.982  3.980  0.298     0.965
# 2  1.172  1.598  0.247     0.857
# 3  2.532  2.873 -0.398     0.850
# 4  1.851  2.376  0.384     0.810

# %%
#build data generators for training and validaton

split = 0.5

df = pd.read_csv('../data/SedMLdata.csv')
columns=["D2mm", "D5mm", "D10mm", "D16mm",
"D25mm","D50mm", "D75mm", "D84mm", "D90mm",
"D95mm", "D98mm"]

# Define dirs and files
train_data_dir = '../data/CropPics'

# Add our data-augmentation parameters to ImageDataGenerator and split data
train_datagen = ImageDataGenerator(rescale = 1./255.,
                                   horizontal_flip = True,
                                   vertical_flip = True,
                                   validation_split = split)


#set batch Size
batch_size = 16

#set color
# c_ch = 1
# c_mode = 'grayscale'
c_ch = 3
c_mode = 'rgb'

#set Image size (RGB so imshape is 3)
pix_dim = 1024
imsize = (pix_dim, pix_dim) 
imshape = (pix_dim, pix_dim, c_ch)

# Flow training images in batches 
train_generator = train_datagen.flow_from_dataframe(dataframe = df,
                                                    directory = train_data_dir,
                                                    batch_size = batch_size,
                                                    class_mode = 'raw',
                                                    x_col = 'CropName',
                                                    y_col = columns,
                                                    target_size = imsize,
                                                    color_mode = c_mode,
                                                    subset = 'training')

# Flow validation images in batches 
validation_generator =  train_datagen.flow_from_dataframe(dataframe=df,
                                                          directory = train_data_dir,
                                                          batch_size = batch_size,
                                                          class_mode = 'raw',
                                                          x_col = 'CropName',
                                                          y_col = columns,
                                                          target_size = imsize,
                                                          color_mode = c_mode,
                                                          subset = 'validation')
# Out:
# Found 150 validated image filenames.
# Found 150 validated image filenames.

# %%
total_train = 150
total_val = 150

# %%
#show augs

how_many = 1
#how_many = batch size

x = validation_generator.next()

for i in range(0,how_many):
    image = x[0][i]   # batch[0] images, batch[1] labels... 
    plt.imshow(image.squeeze())   #squeeze for grayscale images
    print('Stats :', x[1][i])
    plt.show()
# Out:
# Stats : [0.16  0.177 0.193 0.207 0.224 0.271 0.353 0.424 0.539 0.724 0.949]

# %%
#model

model = tf.keras.Sequential([
    layers.InputLayer(input_shape=imshape),
    layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'),
    #layers.SpatialDropout2D(0.5),
    layers.BatchNormalization(),
    layers.MaxPool2D(),
    
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.SpatialDropout2D(0.5),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.SpatialDropout2D(0.5),
    layers.BatchNormalization(),
    layers.MaxPool2D(),
    
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.SpatialDropout2D(0.5),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.SpatialDropout2D(0.5),
    layers.BatchNormalization(),
    layers.MaxPool2D(),
    
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.SpatialDropout2D(0.5),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.SpatialDropout2D(0.5),
    layers.BatchNormalization(),
    layers.MaxPool2D(),
    
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.SpatialDropout2D(0.5),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.SpatialDropout2D(0.5),
    layers.BatchNormalization(),
    layers.MaxPool2D(),
    
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.SpatialDropout2D(0.5),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.SpatialDropout2D(0.5),
    layers.BatchNormalization(),
    layers.MaxPool2D(),
    
    layers.GlobalMaxPooling2D(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(len(columns), activation="linear")
])


model._name = "SandCam_CNN"

model.summary()
# Out:
# Model: "SandCam_CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 1024, 1024, 32)    896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024, 1024, 32)    128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 512, 512, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 512, 512, 64)      18496
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 512, 512, 64)      36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512, 512, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256, 256, 64)      256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# global_max_pooling2d (Global (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33280
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 11)                715
# =================================================================
# Total params: 461,067
# Trainable params: 460,363
# Non-trainable params: 704
# _________________________________________________________________

# %%
# #determine the learning rate

# callbacks = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch/10))

# model.compile(loss = 'mean_squared_error',
#              optimizer = tf.keras.optimizers.Adam(lr = 1e-8),
#              metrics = mae_metric)

# history = model.fit(train_generator,
#                     steps_per_epoch = total_train // batch_size,
#                     validation_data = validation_generator,
#                     epochs= 100,
#                     workers = 8,
#                     validation_steps =  total_val // batch_size,
#                     callbacks =[callbacks])

# %%
#LOSS CURVE

# %%
# define other metrics
metrics = tf.keras.metrics.MeanAbsolutePercentageError(name='mape')

# %%
#compile
model.compile(loss='mean_squared_error', 
              optimizer=tf.keras.optimizers.Adam(),
              metrics = metrics
             )

# %%
# define a callback

early_stop = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', 
                                             patience = 20, 
                                             restore_best_weights = True)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                 factor = 0.2,
                                                 verbose = 1,
                                                 patience = 5)

# %%
#train the model
history = model.fit(train_generator,
                    steps_per_epoch = total_train // batch_size,
                    validation_data = validation_generator,
                    epochs= 200,
                    workers = 8,
                    validation_steps =  total_val // batch_size,
                    callbacks =[early_stop, reduce_lr])
# Out:
# Epoch 1/200
# 9/9 [==============================] - 5s 584ms/step - loss: 6.5730 - mape: 550.2749 - val_loss: 1.3165 - val_mape: 99.7984
# Epoch 2/200
# 9/9 [==============================] - 4s 468ms/step - loss: 1.2279 - mape: 212.3699 - val_loss: 1.3065 - val_mape: 97.5661
# Epoch 3/200
# 9/9 [==============================] - 4s 498ms/step - loss: 0.8580 - mape: 134.0227 - val_loss: 1.3049 - val_mape: 95.9823
# Epoch 4/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.7353 - mape: 124.3852 - val_loss: 1.3000 - val_mape: 94.6455
# Epoch 5/200
# 9/9 [==============================] - 4s 461ms/step - loss: 0.7220 - mape: 120.3671 - val_loss: 1.1958 - val_mape: 91.8166
# Epoch 6/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.7690 - mape: 121.5845 - val_loss: 1.2432 - val_mape: 89.2217
# Epoch 7/200
# 9/9 [==============================] - 4s 467ms/step - loss: 0.6052 - mape: 111.3761 - val_loss: 1.1793 - val_mape: 85.0294
# Epoch 8/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.6046 - mape: 115.7773 - val_loss: 1.1548 - val_mape: 82.4790
# Epoch 9/200
# 9/9 [==============================] - 4s 464ms/step - loss: 0.5665 - mape: 107.7647 - val_loss: 1.0875 - val_mape: 81.9488
# Epoch 10/200
# 9/9 [==============================] - 4s 467ms/step - loss: 0.6468 - mape: 106.7685 - val_loss: 1.1133 - val_mape: 78.8159
# Epoch 11/200
# 9/9 [==============================] - 4s 460ms/step - loss: 0.5229 - mape: 99.5349 - val_loss: 1.0819 - val_mape: 75.6614
# Epoch 12/200
# 9/9 [==============================] - 4s 467ms/step - loss: 0.5306 - mape: 106.2038 - val_loss: 1.0665 - val_mape: 74.9166
# Epoch 13/200
# 9/9 [==============================] - 4s 471ms/step - loss: 0.5385 - mape: 90.9485 - val_loss: 1.0406 - val_mape: 74.2927
# Epoch 14/200
# 9/9 [==============================] - 4s 486ms/step - loss: 0.4889 - mape: 94.8973 - val_loss: 1.0168 - val_mape: 69.8345
# Epoch 15/200
# 9/9 [==============================] - 4s 474ms/step - loss: 0.4260 - mape: 90.3687 - val_loss: 0.9859 - val_mape: 67.7174
# Epoch 16/200
# 9/9 [==============================] - 4s 456ms/step - loss: 0.4975 - mape: 88.2705 - val_loss: 1.0430 - val_mape: 69.0654
# Epoch 17/200
# 9/9 [==============================] - 4s 463ms/step - loss: 0.4653 - mape: 91.2874 - val_loss: 0.9937 - val_mape: 67.7445
# Epoch 18/200
# 9/9 [==============================] - 4s 459ms/step - loss: 0.4870 - mape: 83.5136 - val_loss: 1.0169 - val_mape: 65.8751
# Epoch 19/200
# 9/9 [==============================] - 4s 464ms/step - loss: 0.4395 - mape: 82.7919 - val_loss: 1.0552 - val_mape: 68.1148
# Epoch 20/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4046 - mape: 91.7429
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 9/9 [==============================] - 4s 470ms/step - loss: 0.4046 - mape: 91.7429 - val_loss: 1.0556 - val_mape: 70.7442
# Epoch 21/200
# 9/9 [==============================] - 4s 487ms/step - loss: 0.4327 - mape: 80.5846 - val_loss: 1.0652 - val_mape: 70.5501
# Epoch 22/200
# 9/9 [==============================] - 4s 458ms/step - loss: 0.4481 - mape: 74.4851 - val_loss: 1.0662 - val_mape: 70.4061
# Epoch 23/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.4295 - mape: 79.9750 - val_loss: 1.0792 - val_mape: 69.5933
# Epoch 24/200
# 9/9 [==============================] - 4s 464ms/step - loss: 0.3944 - mape: 81.6761 - val_loss: 1.0698 - val_mape: 69.5010
# Epoch 25/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3865 - mape: 73.9159
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 9/9 [==============================] - 4s 463ms/step - loss: 0.3865 - mape: 73.9159 - val_loss: 1.0233 - val_mape: 68.9794
# Epoch 26/200
# 9/9 [==============================] - 4s 488ms/step - loss: 0.4226 - mape: 76.2920 - val_loss: 1.0469 - val_mape: 68.9695
# Epoch 27/200
# 9/9 [==============================] - 4s 469ms/step - loss: 0.4099 - mape: 76.2493 - val_loss: 1.0337 - val_mape: 69.0043
# Epoch 28/200
# 9/9 [==============================] - 4s 462ms/step - loss: 0.3786 - mape: 71.3276 - val_loss: 0.9509 - val_mape: 68.9596
# Epoch 29/200
# 9/9 [==============================] - 4s 469ms/step - loss: 0.4289 - mape: 73.9270 - val_loss: 1.0559 - val_mape: 68.7956
# Epoch 30/200
# 9/9 [==============================] - 4s 487ms/step - loss: 0.3289 - mape: 74.7788 - val_loss: 1.0831 - val_mape: 69.3418
# Epoch 31/200
# 9/9 [==============================] - 4s 494ms/step - loss: 0.3605 - mape: 74.7374 - val_loss: 1.0883 - val_mape: 69.6047
# Epoch 32/200
# 9/9 [==============================] - 4s 471ms/step - loss: 0.4107 - mape: 79.7362 - val_loss: 1.0877 - val_mape: 69.4531
# Epoch 33/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3667 - mape: 74.2540
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 9/9 [==============================] - 4s 468ms/step - loss: 0.3667 - mape: 74.2540 - val_loss: 1.0448 - val_mape: 69.2169
# Epoch 34/200
# 9/9 [==============================] - 4s 462ms/step - loss: 0.3755 - mape: 78.3566 - val_loss: 1.0350 - val_mape: 69.3099
# Epoch 35/200
# 9/9 [==============================] - 4s 462ms/step - loss: 0.3743 - mape: 70.2752 - val_loss: 1.0718 - val_mape: 69.8163
# Epoch 36/200
# 9/9 [==============================] - 4s 461ms/step - loss: 0.3714 - mape: 78.3799 - val_loss: 1.0732 - val_mape: 70.0605
# Epoch 37/200
# 9/9 [==============================] - 4s 470ms/step - loss: 0.4107 - mape: 77.4369 - val_loss: 1.0521 - val_mape: 69.8612
# Epoch 38/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3899 - mape: 77.8967
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 9/9 [==============================] - 4s 470ms/step - loss: 0.3899 - mape: 77.8967 - val_loss: 1.0816 - val_mape: 69.8751
# Epoch 39/200
# 9/9 [==============================] - 4s 460ms/step - loss: 0.3969 - mape: 75.4688 - val_loss: 1.0300 - val_mape: 69.5289
# Epoch 40/200
# 9/9 [==============================] - 4s 467ms/step - loss: 0.3786 - mape: 78.5265 - val_loss: 1.0335 - val_mape: 69.0238
# Epoch 41/200
# 9/9 [==============================] - 4s 458ms/step - loss: 0.3893 - mape: 75.8368 - val_loss: 1.0681 - val_mape: 68.6598
# Epoch 42/200
# 9/9 [==============================] - 4s 489ms/step - loss: 0.4289 - mape: 81.1761 - val_loss: 1.0025 - val_mape: 67.3928
# Epoch 43/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4215 - mape: 75.9036
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 9/9 [==============================] - 4s 464ms/step - loss: 0.4215 - mape: 75.9036 - val_loss: 1.0314 - val_mape: 66.4604
# Epoch 44/200
# 9/9 [==============================] - 4s 462ms/step - loss: 0.3739 - mape: 75.4105 - val_loss: 0.9875 - val_mape: 64.9199
# Epoch 45/200
# 9/9 [==============================] - 4s 464ms/step - loss: 0.3966 - mape: 78.0761 - val_loss: 0.9301 - val_mape: 63.0533
# Epoch 46/200
# 9/9 [==============================] - 4s 467ms/step - loss: 0.3729 - mape: 79.8028 - val_loss: 0.9594 - val_mape: 61.2063
# Epoch 47/200
# 9/9 [==============================] - 4s 463ms/step - loss: 0.3583 - mape: 75.6695 - val_loss: 0.9432 - val_mape: 59.7414
# Epoch 48/200
# 9/9 [==============================] - 4s 460ms/step - loss: 0.3411 - mape: 79.6954 - val_loss: 0.9038 - val_mape: 57.7449
# Epoch 49/200
# 9/9 [==============================] - 4s 468ms/step - loss: 0.3762 - mape: 75.8100 - val_loss: 0.8615 - val_mape: 55.7928
# Epoch 50/200
# 9/9 [==============================] - 4s 492ms/step - loss: 0.3444 - mape: 74.3069 - val_loss: 0.8255 - val_mape: 53.8843
# Epoch 51/200
# 9/9 [==============================] - 4s 469ms/step - loss: 0.3907 - mape: 75.2842 - val_loss: 0.8199 - val_mape: 52.8593
# Epoch 52/200
# 9/9 [==============================] - 4s 464ms/step - loss: 0.3844 - mape: 78.4178 - val_loss: 0.8026 - val_mape: 51.7425
# Epoch 53/200
# 9/9 [==============================] - 4s 468ms/step - loss: 0.3899 - mape: 77.3601 - val_loss: 0.7723 - val_mape: 50.3852
# Epoch 54/200
# 9/9 [==============================] - 4s 469ms/step - loss: 0.3414 - mape: 73.9707 - val_loss: 0.7176 - val_mape: 49.4233
# Epoch 55/200
# 9/9 [==============================] - 4s 463ms/step - loss: 0.3722 - mape: 80.8285 - val_loss: 0.7048 - val_mape: 48.4356
# Epoch 56/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.3983 - mape: 79.8715 - val_loss: 0.7051 - val_mape: 47.7913
# Epoch 57/200
# 9/9 [==============================] - 4s 469ms/step - loss: 0.3849 - mape: 79.7143 - val_loss: 0.6481 - val_mape: 46.7593
# Epoch 58/200
# 9/9 [==============================] - 4s 462ms/step - loss: 0.3959 - mape: 82.6916 - val_loss: 0.6811 - val_mape: 46.5100
# Epoch 59/200
# 9/9 [==============================] - 4s 466ms/step - loss: 0.3918 - mape: 76.8311 - val_loss: 0.6620 - val_mape: 46.3510
# Epoch 60/200
# 9/9 [==============================] - 4s 486ms/step - loss: 0.4009 - mape: 77.0683 - val_loss: 0.6670 - val_mape: 46.1426
# Epoch 61/200
# 9/9 [==============================] - 4s 460ms/step - loss: 0.3791 - mape: 75.7131 - val_loss: 0.6575 - val_mape: 46.4876
# Epoch 62/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.3706 - mape: 80.1597 - val_loss: 0.6204 - val_mape: 45.6102
# Epoch 63/200
# 9/9 [==============================] - 4s 462ms/step - loss: 0.4050 - mape: 76.5561 - val_loss: 0.6191 - val_mape: 45.9413
# Epoch 64/200
# 9/9 [==============================] - 4s 468ms/step - loss: 0.3824 - mape: 82.4343 - val_loss: 0.6111 - val_mape: 45.8232
# Epoch 65/200
# 9/9 [==============================] - 4s 466ms/step - loss: 0.3781 - mape: 72.9539 - val_loss: 0.6274 - val_mape: 45.4550
# Epoch 66/200
# 9/9 [==============================] - 4s 464ms/step - loss: 0.3592 - mape: 76.8985 - val_loss: 0.5716 - val_mape: 45.2619
# Epoch 67/200
# 9/9 [==============================] - 4s 461ms/step - loss: 0.3830 - mape: 78.7815 - val_loss: 0.5856 - val_mape: 45.1943
# Epoch 68/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.4008 - mape: 80.7317 - val_loss: 0.6086 - val_mape: 45.5167
# Epoch 69/200
# 9/9 [==============================] - 4s 480ms/step - loss: 0.3736 - mape: 74.3535 - val_loss: 0.5882 - val_mape: 45.1400
# Epoch 70/200
# 9/9 [==============================] - 4s 487ms/step - loss: 0.3168 - mape: 73.1933 - val_loss: 0.5685 - val_mape: 45.4081
# Epoch 71/200
# 9/9 [==============================] - 4s 463ms/step - loss: 0.3675 - mape: 76.0236 - val_loss: 0.5267 - val_mape: 45.1076
# Epoch 72/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.3355 - mape: 78.6147 - val_loss: 0.5655 - val_mape: 44.6495
# Epoch 73/200
# 9/9 [==============================] - 4s 466ms/step - loss: 0.3847 - mape: 73.3503 - val_loss: 0.5297 - val_mape: 44.6826
# Epoch 74/200
# 9/9 [==============================] - 4s 468ms/step - loss: 0.3535 - mape: 74.1149 - val_loss: 0.5322 - val_mape: 44.2812
# Epoch 75/200
# 9/9 [==============================] - 4s 466ms/step - loss: 0.3840 - mape: 74.1893 - val_loss: 0.5621 - val_mape: 44.5460
# Epoch 76/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2964 - mape: 76.6702
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 9/9 [==============================] - 4s 460ms/step - loss: 0.2964 - mape: 76.6702 - val_loss: 0.5480 - val_mape: 44.4600
# Epoch 77/200
# 9/9 [==============================] - 4s 487ms/step - loss: 0.3732 - mape: 75.7875 - val_loss: 0.5039 - val_mape: 43.8709
# Epoch 78/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.3821 - mape: 80.3801 - val_loss: 0.5451 - val_mape: 44.0061
# Epoch 79/200
# 9/9 [==============================] - 4s 483ms/step - loss: 0.4267 - mape: 82.1505 - val_loss: 0.5306 - val_mape: 43.8200
# Epoch 80/200
# 9/9 [==============================] - 4s 490ms/step - loss: 0.3401 - mape: 72.4404 - val_loss: 0.5313 - val_mape: 43.6101
# Epoch 81/200
# 9/9 [==============================] - 4s 460ms/step - loss: 0.3259 - mape: 71.9600 - val_loss: 0.5130 - val_mape: 43.1699
# Epoch 82/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3755 - mape: 75.1740
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 9/9 [==============================] - 4s 464ms/step - loss: 0.3755 - mape: 75.1740 - val_loss: 0.5301 - val_mape: 43.0196
# Epoch 83/200
# 9/9 [==============================] - 4s 457ms/step - loss: 0.3803 - mape: 77.6870 - val_loss: 0.5364 - val_mape: 43.3008
# Epoch 84/200
# 9/9 [==============================] - 4s 464ms/step - loss: 0.3645 - mape: 72.2976 - val_loss: 0.5318 - val_mape: 43.2287
# Epoch 85/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.3861 - mape: 81.6582 - val_loss: 0.5069 - val_mape: 42.3962
# Epoch 86/200
# 9/9 [==============================] - 4s 462ms/step - loss: 0.3339 - mape: 78.9468 - val_loss: 0.5246 - val_mape: 42.5567
# Epoch 87/200
# 9/9 [==============================] - 4s 459ms/step - loss: 0.4029 - mape: 76.6185 - val_loss: 0.4815 - val_mape: 42.4000
# Epoch 88/200
# 9/9 [==============================] - 4s 464ms/step - loss: 0.4054 - mape: 79.4293 - val_loss: 0.4712 - val_mape: 41.9481
# Epoch 89/200
# 9/9 [==============================] - 4s 469ms/step - loss: 0.3896 - mape: 79.6786 - val_loss: 0.5038 - val_mape: 41.7138
# Epoch 90/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.4565 - mape: 79.3274 - val_loss: 0.4966 - val_mape: 41.9831
# Epoch 91/200
# 9/9 [==============================] - 4s 485ms/step - loss: 0.3753 - mape: 79.2900 - val_loss: 0.4980 - val_mape: 42.0698
# Epoch 92/200
# 9/9 [==============================] - 4s 493ms/step - loss: 0.3721 - mape: 76.9060 - val_loss: 0.5050 - val_mape: 41.8949
# Epoch 93/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3482 - mape: 75.8487
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 9/9 [==============================] - 4s 463ms/step - loss: 0.3482 - mape: 75.8487 - val_loss: 0.5070 - val_mape: 41.3071
# Epoch 94/200
# 9/9 [==============================] - 4s 467ms/step - loss: 0.3759 - mape: 75.3044 - val_loss: 0.5048 - val_mape: 41.1771
# Epoch 95/200
# 9/9 [==============================] - 4s 492ms/step - loss: 0.3537 - mape: 73.0527 - val_loss: 0.4875 - val_mape: 41.2117
# Epoch 96/200
# 9/9 [==============================] - 4s 462ms/step - loss: 0.3666 - mape: 73.3138 - val_loss: 0.4997 - val_mape: 41.5045
# Epoch 97/200
# 9/9 [==============================] - 4s 497ms/step - loss: 0.3842 - mape: 71.9681 - val_loss: 0.5078 - val_mape: 41.5522
# Epoch 98/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3403 - mape: 80.5674
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 9/9 [==============================] - 4s 462ms/step - loss: 0.3403 - mape: 80.5674 - val_loss: 0.4900 - val_mape: 40.8159
# Epoch 99/200
# 9/9 [==============================] - 4s 464ms/step - loss: 0.3553 - mape: 74.7347 - val_loss: 0.4968 - val_mape: 41.1410
# Epoch 100/200
# 9/9 [==============================] - 4s 466ms/step - loss: 0.4137 - mape: 82.2565 - val_loss: 0.5014 - val_mape: 41.4683
# Epoch 101/200
# 9/9 [==============================] - 4s 471ms/step - loss: 0.3448 - mape: 77.4627 - val_loss: 0.4685 - val_mape: 40.6007
# Epoch 102/200
# 9/9 [==============================] - 4s 466ms/step - loss: 0.3290 - mape: 77.9992 - val_loss: 0.4957 - val_mape: 41.1724
# Epoch 103/200
# 9/9 [==============================] - 4s 467ms/step - loss: 0.4223 - mape: 77.1892 - val_loss: 0.4889 - val_mape: 40.9995
# Epoch 104/200
# 9/9 [==============================] - 4s 471ms/step - loss: 0.3890 - mape: 74.6521 - val_loss: 0.4522 - val_mape: 40.8261
# Epoch 105/200
# 9/9 [==============================] - 4s 457ms/step - loss: 0.3925 - mape: 75.1375 - val_loss: 0.4831 - val_mape: 40.8926
# Epoch 106/200
# 9/9 [==============================] - 4s 456ms/step - loss: 0.3986 - mape: 78.3578 - val_loss: 0.4910 - val_mape: 40.8870
# Epoch 107/200
# 9/9 [==============================] - 4s 463ms/step - loss: 0.4177 - mape: 71.0798 - val_loss: 0.5014 - val_mape: 40.9104
# Epoch 108/200
# 9/9 [==============================] - 4s 468ms/step - loss: 0.3922 - mape: 76.4103 - val_loss: 0.4781 - val_mape: 40.5383
# Epoch 109/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3999 - mape: 73.3407
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# 9/9 [==============================] - 4s 467ms/step - loss: 0.3999 - mape: 73.3407 - val_loss: 0.4956 - val_mape: 41.1434
# Epoch 110/200
# 9/9 [==============================] - 4s 472ms/step - loss: 0.4071 - mape: 73.9830 - val_loss: 0.4953 - val_mape: 40.9025
# Epoch 111/200
# 9/9 [==============================] - 4s 467ms/step - loss: 0.3804 - mape: 75.8004 - val_loss: 0.4865 - val_mape: 40.3083
# Epoch 112/200
# 9/9 [==============================] - 4s 467ms/step - loss: 0.3465 - mape: 72.7486 - val_loss: 0.4924 - val_mape: 40.7358
# Epoch 113/200
# 9/9 [==============================] - 4s 467ms/step - loss: 0.3605 - mape: 79.1586 - val_loss: 0.4940 - val_mape: 40.1564
# Epoch 114/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3225 - mape: 80.4406
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# 9/9 [==============================] - 4s 466ms/step - loss: 0.3225 - mape: 80.4406 - val_loss: 0.4907 - val_mape: 40.0859
# Epoch 115/200
# 9/9 [==============================] - 4s 466ms/step - loss: 0.4360 - mape: 79.1213 - val_loss: 0.4915 - val_mape: 40.4721
# Epoch 116/200
# 9/9 [==============================] - 4s 466ms/step - loss: 0.3833 - mape: 77.5315 - val_loss: 0.4817 - val_mape: 40.5903
# Epoch 117/200
# 9/9 [==============================] - 4s 464ms/step - loss: 0.3822 - mape: 74.3693 - val_loss: 0.4586 - val_mape: 40.6784
# Epoch 118/200
# 9/9 [==============================] - 4s 461ms/step - loss: 0.3867 - mape: 76.2438 - val_loss: 0.4913 - val_mape: 40.6802
# Epoch 119/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4491 - mape: 77.8154
# Epoch 00119: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# 9/9 [==============================] - 4s 463ms/step - loss: 0.4491 - mape: 77.8154 - val_loss: 0.4834 - val_mape: 40.4044
# Epoch 120/200
# 9/9 [==============================] - 4s 468ms/step - loss: 0.4494 - mape: 79.9650 - val_loss: 0.4931 - val_mape: 40.6844
# Epoch 121/200
# 9/9 [==============================] - 4s 465ms/step - loss: 0.3428 - mape: 73.8883 - val_loss: 0.4714 - val_mape: 40.6634
# Epoch 122/200
# 9/9 [==============================] - 4s 459ms/step - loss: 0.3478 - mape: 79.6990 - val_loss: 0.4858 - val_mape: 40.4541
# Epoch 123/200
# 9/9 [==============================] - 4s 470ms/step - loss: 0.3950 - mape: 76.3270 - val_loss: 0.4814 - val_mape: 40.4908
# Epoch 124/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3354 - mape: 75.4021
# Epoch 00124: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# 9/9 [==============================] - 4s 471ms/step - loss: 0.3354 - mape: 75.4021 - val_loss: 0.4980 - val_mape: 40.8647

# %%
#look at the metrics from training
# %matplotlib inline

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.ylim(0,1)

plt.title('Training and validation loss (MSE)')
plt.legend(loc=0)
plt.figure()
plt.show()

mae = history.history['mape']
val_mae = history.history['val_mape']

plt.plot(epochs, mae, 'r', label='Training MAPE')
plt.plot(epochs, val_mae, 'b', label='Validation MAPE')
plt.ylim(0,100)

plt.title('Training and validation mape')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
#Eventually, we will use model.evaluate() with the Duck Field samples... 
#until they are processed, we just use the validation egnerator as a sanity check

SC = validation_generator.next()

how_many = 2
#how_many = batch size

for i in range(0,how_many):
    image = x[0][i]   # batch[0] images, batch[1] labels... 
    #make a prediction
    img = np.expand_dims(image,axis=0)
    predStats = model.predict(img)
    
    plt.imshow(image.squeeze())   #squeeze for grayscale images  
    print('Stats :',x[1][i])
    print('Predicted Stats:', predStats)
    plt.show()
# Out:
# Stats : [0.16  0.177 0.193 0.207 0.224 0.271 0.353 0.424 0.539 0.724 0.949]
# Predicted Stats: [[0.0434134  0.1029904  0.04360491 0.10569336 0.0733961  0.09980799
#   0.16266681 0.21041179 0.22937348 0.26428133 0.30247927]]
# Stats : [0.171 0.198 0.226 0.253 0.29  0.413 0.854 1.364 2.593 3.626 5.19 ]
# Predicted Stats: [[0.1873445  0.10227431 0.26542845 0.14657593 0.25478318 0.34073237
#   0.54065937 0.76754826 0.8035167  0.98669106 1.3336695 ]]

# %%
#save the model
filepath = './models/SNmodel'
model.save(filepath)

# %%
# #model size
# model.save("./models/SNmodel.h5")
# model_file ='./models/SNmodel.h5'
# b = os.path.getsize(model_file)
# print ("Size(mb): %d" % (b/1000000))

# %%
#prune

# %%
#quantize

# %%
#test Quantize
